# %%
import pandas as pd

# %%
df = pd.read_excel('DH2.xlsx')

# %%
df=df.dropna(how='any')

# %%
df
# Out:
#             DATE 2015-10-26 00:00:00 2015-10-27 00:00:00  \
# 2   CONTI B/FAST    TOAST,BUTTER&JAM    TOAST,BUTTER&JAM
# 3    MAIN COURSE  ALOO ONION PARATHA           VERMISELY
# 4        ACCOMP.       GREEN CHUTNEY             CHUTNEY
# 7          SALAD         GREEN SALAD         LACHA ONION
# 8           CURD         JEERA RAITA       MIX VEG RAITA
# 9           RICE          PLAIN RICE          STEAM RICE
# 10         BREAD             CHAPATI             CHAPATI
# 11         DAL 1        RAJMA MASALA    MOONG CHILKA DAL
# 12         DAL 2               RASAM             SAMBHAR
# 13           VEG             MIX VEG       MUTTER PANEER
# 14       NON-VEG      BUTTER CHICKEN           EGG CURRY
# 15       ACCOMP.              PICKLE         SAVIA KHEER
# 17         SALAD           MIX SALAD      CUCUMBER SALAD
# 18          CURD      CUCUMBAR RAITA         BUTTER MILK
# 19          RICE       MUTTER PULAO          STEAM  RICE
# 20         BREAD             CHAPATI             CHAPATI
# 21         DAL 1        WHITE MUTTER      RED MASOOR DAL
# 22         DAL 2             SAMBHAR               RASAM
# 23           VEG          ALOO PALAK           SOYA ALLO
# 24       NON-VEG          EGG MASALA       CHICKEN CURRY
# 25       ACCOMP.              Pickle              PICKLE
#
#         2015-10-28 00:00:00 2015-10-29 00:00:00 2015-10-30 00:00:00  \
# 2          TOAST,BUTTER&JAM    TOAST,BUTTER&JAM    TOAST,BUTTER&JAM
# 3                     POORI                P0HA              UTTPAM
# 4                     BHAJI             CHUTNEY             SAMBHAR
# 7            CUCUMBAR SALAD        SPROUT SALAD           MIX SALAD
# 8               ONION RAITA          MINT RAITA        BOONDI RAITA
# 9                STEAM RICE          JEERA RICE          STEAM RICE
# 10                  CHAPATI             CHAPATI             CHAPATI
# 11               KADI PALAK   CHOLEY AMRIT SARI           DAL TADKA
# 12                    RASAM             SAMBHAR               RASAM
# 13               ALOO JEERA  KHTTA MEETHA PETHA         ALOO GOBHI
# 14               FISH CURRY      CHICKEN MASALA             SAMBHAR
# 15                   PICKLE              PICKLE              PICKLE
# 17               MIX SALAD         FINGER SALAD          CUBE SALAD
# 18             TOMATO RAITA         JEERA RAITA         TADKA RAITA
# 19          CORRIENDER RICE          PLAIN RICE          STEAM RICE
# 20                  CHAPATI             CHAPATI             CHAPATI
# 21                DHABA DAL           CHANA DAL      DAL PANCHRATAN
# 22                   SAMBAR               RASAM               RASAM
# 23              GHIYA KOFTA            MIX VEG      BHINDI DO PYAZA
# 24      CHICKEN ROGAN  JOSH       PALAK CHICKEN      CHICKEN MASALA
# 25                   PICKLE              PICKLE              PICKLE
#
#    2015-10-31 00:00:00 2015-11-01 00:00:00
# 2     TOAST,BUTTER&JAM    TOAST,BUTTER&JAM
# 3          SOOJI UPPMA              CHOLEY
# 4          RED CHUTNEY             BHATURE
# 7          LACHA ONION           MIX SALAD
# 8           MINT RAITA        BOONDI RAITA
# 9           STEAM RICE         VEG BRIYANI
# 10             CHAPATI             CHAPATI
# 11        RAJMA RASILA             MIX DAL
# 12               RASAM             SAMBHAR
# 13      NUTRILA MUTTER          ALOO BEENS
# 14       CHICKEN CURRY    CHICKEN  BRIYANI
# 15              PICKLE              PICKLE
# 17          CUBE SALAD      CUCUMBER SALAD
# 18      CUCUMBER RAITA        MASALA RAITA
# 19          STEAM RICE           STEM RICE
# 20             CHAPATI             CHAPATI
# 21        BLACK MASSOR           DAL TRNGA
# 22               RASAM             SAMBHAR
# 23         ALLO BAIGAN           VEG KOFTA
# 24           EGG CURRY       CHICKEN CURRY
# 25              PICKLE              PICKLE

# %%
z=df.iloc[:,(1,2,3,4,5,6,7)]

# %%
z.columns=['Mon','Tue','Wed','Thu','Fri','Sat','Sun']

# %%
#z.to_json("week.json")
jsond=z.to_json()

# %%
jsond
# Out:
# '{"Mon":{"2":"TOAST,BUTTER&JAM","3":"ALOO ONION PARATHA","4":"GREEN CHUTNEY","7":"GREEN SALAD","8":"JEERA RAITA","9":"PLAIN RICE","10":"CHAPATI","11":"RAJMA MASALA","12":"RASAM","13":"MIX VEG","14":"BUTTER CHICKEN","15":"PICKLE","17":"MIX SALAD","18":"CUCUMBAR RAITA","19":"MUTTER PULAO ","20":"CHAPATI","21":"WHITE MUTTER","22":"SAMBHAR","23":"ALOO PALAK","24":"EGG MASALA","25":"Pickle"},"Tue":{"2":"TOAST,BUTTER&JAM","3":"VERMISELY","4":"CHUTNEY","7":"LACHA ONION","8":"MIX VEG RAITA","9":" STEAM RICE","10":"CHAPATI","11":"MOONG CHILKA DAL","12":"SAMBHAR","13":"MUTTER PANEER","14":"EGG CURRY","15":"SAVIA KHEER","17":"CUCUMBER SALAD","18":"BUTTER MILK","19":"STEAM  RICE","20":"CHAPATI","21":"RED MASOOR DAL","22":"RASAM","23":" SOYA ALLO","24":"CHICKEN CURRY","25":"PICKLE"},"Wed":{"2":"TOAST,BUTTER&JAM","3":"POORI","4":"BHAJI","7":"CUCUMBAR SALAD","8":"ONION RAITA","9":"STEAM RICE","10":"CHAPATI","11":"KADI PALAK","12":"RASAM","13":"ALOO JEERA","14":" FISH CURRY","15":"PICKLE","17":"MIX SALAD ","18":"TOMATO RAITA","19":"        CORRIENDER RICE","20":"CHAPATI","21":"DHABA DAL","22":"SAMBAR","23":"GHIYA KOFTA","24":"CHICKEN ROGAN  JOSH","25":"PICKLE"},"Thu":{"2":"TOAST,BUTTER&JAM","3":"P0HA","4":"CHUTNEY","7":"SPROUT SALAD","8":"MINT RAITA","9":"JEERA RICE","10":"CHAPATI","11":"CHOLEY AMRIT SARI","12":"SAMBHAR","13":"KHTTA MEETHA PETHA","14":"CHICKEN MASALA","15":"PICKLE","17":"FINGER SALAD","18":"JEERA RAITA","19":"PLAIN RICE","20":"CHAPATI","21":"CHANA DAL","22":"RASAM","23":"MIX VEG ","24":"PALAK CHICKEN","25":"PICKLE"},"Fri":{"2":"TOAST,BUTTER&JAM","3":"UTTPAM","4":"SAMBHAR","7":"MIX SALAD","8":"BOONDI RAITA","9":"STEAM RICE","10":"CHAPATI","11":"DAL TADKA","12":"RASAM","13":"ALOO GOBHI ","14":"SAMBHAR","15":"PICKLE","17":"CUBE SALAD","18":"TADKA RAITA","19":"STEAM RICE","20":"CHAPATI","21":"DAL PANCHRATAN","22":"RASAM","23":"BHINDI DO PYAZA","24":"CHICKEN MASALA","25":"PICKLE"},"Sat":{"2":"TOAST,BUTTER&JAM","3":"SOOJI UPPMA","4":"RED CHUTNEY","7":"LACHA ONION","8":"MINT RAITA","9":"STEAM RICE","10":"CHAPATI","11":"RAJMA RASILA","12":"RASAM","13":"NUTRILA MUTTER","14":"CHICKEN CURRY","15":"PICKLE","17":"CUBE SALAD","18":"CUCUMBER RAITA","19":"STEAM RICE","20":"CHAPATI","21":"BLACK MASSOR","22":"RASAM","23":"ALLO BAIGAN","24":"EGG CURRY","25":"PICKLE"},"Sun":{"2":"TOAST,BUTTER&JAM","3":"CHOLEY","4":"BHATURE","7":"MIX SALAD","8":"BOONDI RAITA","9":"VEG BRIYANI","10":"CHAPATI","11":"MIX DAL","12":"SAMBHAR","13":"ALOO BEENS","14":"CHICKEN  BRIYANI","15":"PICKLE","17":"CUCUMBER SALAD","18":"MASALA RAITA","19":"STEM RICE","20":"CHAPATI","21":"DAL TRNGA","22":"SAMBHAR","23":"VEG KOFTA","24":"CHICKEN CURRY","25":"PICKLE"}}'

# %%
import json

# %%
from pprint import pprint

with open('week.json') as data_file:    
    data = json.load(data_file)

pprint(data)
# Out:
# {'Fri': {'10': 'CHAPATI',
#          '11': 'DAL TADKA',
#          '12': 'RASAM',
#          '13': 'ALOO GOBHI ',
#          '14': 'SAMBHAR',
#          '15': 'PICKLE',
#          '17': 'CUBE SALAD',
#          '18': 'TADKA RAITA',
#          '19': 'STEAM RICE',
#          '2': 'TOAST,BUTTER&JAM',
#          '20': 'CHAPATI',
#          '21': 'DAL PANCHRATAN',
#          '22': 'RASAM',
#          '23': 'BHINDI DO PYAZA',
#          '24': 'CHICKEN MASALA',
#          '25': 'PICKLE',
#          '3': 'UTTPAM',
#          '4': 'SAMBHAR',
#          '7': 'MIX SALAD',
#          '8': 'BOONDI RAITA',
#          '9': 'STEAM RICE'},
#  'Mon': {'10': 'CHAPATI',
#          '11': 'RAJMA MASALA',
#          '12': 'RASAM',
#          '13': 'MIX VEG',
#          '14': 'BUTTER CHICKEN',
#          '15': 'PICKLE',
#          '17': 'MIX SALAD',
#          '18': 'CUCUMBAR RAITA',
#          '19': 'MUTTER PULAO ',
#          '2': 'TOAST,BUTTER&JAM',
#          '20': 'CHAPATI',
#          '21': 'WHITE MUTTER',
#          '22': 'SAMBHAR',
#          '23': 'ALOO PALAK',
#          '24': 'EGG MASALA',
#          '25': 'Pickle',
#          '3': 'ALOO ONION PARATHA',
#          '4': 'GREEN CHUTNEY',
#          '7': 'GREEN SALAD',
#          '8': 'JEERA RAITA',
#          '9': 'PLAIN RICE'},
#  'Sat': {'10': 'CHAPATI',
#          '11': 'RAJMA RASILA',
#          '12': 'RASAM',
#          '13': 'NUTRILA MUTTER',
#          '14': 'CHICKEN CURRY',
#          '15': 'PICKLE',
#          '17': 'CUBE SALAD',
#          '18': 'CUCUMBER RAITA',
#          '19': 'STEAM RICE',
#          '2': 'TOAST,BUTTER&JAM',
#          '20': 'CHAPATI',
#          '21': 'BLACK MASSOR',
#          '22': 'RASAM',
#          '23': 'ALLO BAIGAN',
#          '24': 'EGG CURRY',
#          '25': 'PICKLE',
#          '3': 'SOOJI UPPMA',
#          '4': 'RED CHUTNEY',
#          '7': 'LACHA ONION',
#          '8': 'MINT RAITA',
#          '9': 'STEAM RICE'},
#  'Sun': {'10': 'CHAPATI',
#          '11': 'MIX DAL',
#          '12': 'SAMBHAR',
#          '13': 'ALOO BEENS',
#          '14': 'CHICKEN  BRIYANI',
#          '15': 'PICKLE',
#          '17': 'CUCUMBER SALAD',
#          '18': 'MASALA RAITA',
#          '19': 'STEM RICE',
#          '2': 'TOAST,BUTTER&JAM',
#          '20': 'CHAPATI',
#          '21': 'DAL TRNGA',
#          '22': 'SAMBHAR',
#          '23': 'VEG KOFTA',
#          '24': 'CHICKEN CURRY',
#          '25': 'PICKLE',
#          '3': 'CHOLEY',
#          '4': 'BHATURE',
#          '7': 'MIX SALAD',
#          '8': 'BOONDI RAITA',
#          '9': 'VEG BRIYANI'},
#  'Thu': {'10': 'CHAPATI',
#          '11': 'CHOLEY AMRIT SARI',
#          '12': 'SAMBHAR',
#          '13': 'KHTTA MEETHA PETHA',
#          '14': 'CHICKEN MASALA',
#          '15': 'PICKLE',
#          '17': 'FINGER SALAD',
#          '18': 'JEERA RAITA',
#          '19': 'PLAIN RICE',
#          '2': 'TOAST,BUTTER&JAM',
#          '20': 'CHAPATI',
#          '21': 'CHANA DAL',
#          '22': 'RASAM',
#          '23': 'MIX VEG ',
#          '24': 'PALAK CHICKEN',
#          '25': 'PICKLE',
#          '3': 'P0HA',
#          '4': 'CHUTNEY',
#          '7': 'SPROUT SALAD',
#          '8': 'MINT RAITA',
#          '9': 'JEERA RICE'},
#  'Tue': {'10': 'CHAPATI',
#          '11': 'MOONG CHILKA DAL',
#          '12': 'SAMBHAR',
#          '13': 'MUTTER PANEER',
#          '14': 'EGG CURRY',
#          '15': 'SAVIA KHEER',
#          '17': 'CUCUMBER SALAD',
#          '18': 'BUTTER MILK',
#          '19': 'STEAM  RICE',
#          '2': 'TOAST,BUTTER&JAM',
#          '20': 'CHAPATI',
#          '21': 'RED MASOOR DAL',
#          '22': 'RASAM',
#          '23': ' SOYA ALLO',
#          '24': 'CHICKEN CURRY',
#          '25': 'PICKLE',
#          '3': 'VERMISELY',
#          '4': 'CHUTNEY',
#          '7': 'LACHA ONION',
#          '8': 'MIX VEG RAITA',
#          '9': ' STEAM RICE'},
#  'Wed': {'10': 'CHAPATI',
#          '11': 'KADI PALAK',
#          '12': 'RASAM',
#          '13': 'ALOO JEERA',
#          '14': ' FISH CURRY',
#          '15': 'PICKLE',
#          '17': 'MIX SALAD ',
#          '18': 'TOMATO RAITA',
#          '19': 'CORRIENDER RICE',
#          '2': 'TOAST,BUTTER&JAM',
#          '20': 'CHAPATI',
#          '21': 'DHABA DAL',
#          '22': 'SAMBAR',
#          '23': 'GHIYA KOFTA',
#          '24': 'CHICKEN ROGAN  JOSH',
#          '25': 'PICKLE',
#          '3': 'POORI',
#          '4': 'BHAJI',
#          '7': 'CUCUMBAR SALAD',
#          '8': 'ONION RAITA',
#          '9': 'STEAM RICE'}}

# %%
data['Mon']
# Out:
# {'10': 'CHAPATI',
#  '11': 'RAJMA MASALA',
#  '12': 'RASAM',
#  '13': 'MIX VEG',
#  '14': 'BUTTER CHICKEN',
#  '15': 'PICKLE',
#  '17': 'MIX SALAD',
#  '18': 'CUCUMBAR RAITA',
#  '19': 'MUTTER PULAO ',
#  '2': 'TOAST,BUTTER&JAM',
#  '20': 'CHAPATI',
#  '21': 'WHITE MUTTER',
#  '22': 'SAMBHAR',
#  '23': 'ALOO PALAK',
#  '24': 'EGG MASALA',
#  '25': 'Pickle',
#  '3': 'ALOO ONION PARATHA',
#  '4': 'GREEN CHUTNEY',
#  '7': 'GREEN SALAD',
#  '8': 'JEERA RAITA',
#  '9': 'PLAIN RICE'}
