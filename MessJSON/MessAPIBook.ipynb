# %%
import pandas as pd

# %%
dh2 = pd.read_excel('DH2.xlsx')
dh1 = pd.read_excel('DH1.xlsx')

# %%
dh2=dh2.dropna(how='any')
dh1=dh1.dropna(how='any')

# %%
dh1
# Out:
#    SHIV NADAR UNIVERSITY MENU DH-1 FROM 16TH NOV 22ND NOV  \
# 0                                                 DAY
# 3                                       CONTI B/ FAST
# 4                                         MAIN COURSE
# 5                                            BEVERAGE
# 7                                               SALAD
# 8                                                CURD
# 9                                                RICE
# 10                                             DAL -1
# 11                                              DAL_2
# 12                                       SEASONAL VEG
# 13                                              BREAD
# 14                                          NON. VEG.
# 17                                              SALAD
# 18                                               CURD
# 19                                               RICE
# 20                                             DAL -1
# 21                                              DAL_2
# 22                                       SEASONAL VEG
# 23                                              BREAD
# 24                                          NON. VEG.
#
#                    Unnamed: 1          Unnamed: 2          Unnamed: 3  \
# 0                      MONDAY             TUESDAY           WEDNESDAY
# 3          BUTTER Bread & JAM  BUTTER Bread & JAM  BUTTER Bread & JAM
# 4   VERMICELLI UPMA/\nCHUTNEY        VADA SAMBHER           PAV BHAJI
# 5                  TEA/COFFEE          TEA/COFFEE          TEA/COFFEE
# 7                 GREEN SALAD       MACRONI SALAD        LACHHA ONION
# 8                 JEERA RAITA           MIX RAITA      CUCUMBER RAITA
# 9                  PLAIN RICE          JEERA RICE           PEAS RICE
# 10                    SAMBHAR               RASAM              SAMBER
# 11               KADHI PAKORA           DAL TADKA           RED MALKA
# 12                 ALOO JEERA       MIX VEGETABLE          ALOO GOBHI
# 13                    CHAPATI             CHAPATI             CHAPATI
# 14           CHICKEN LABABDAR          FISH CURRY       CHICKEN CURRY
# 17               LACHHA ONION          CUBE SALAD         GREEN SALAD
# 18             CUCUMBER RAITA         JEERA RAITA          MINT RAITA
# 19                  PEAS RICE          ONION RICE         VEG BIRYANI
# 20                    SAMBHAR               RASAM               RASAM
# 21                 LOBIYA DAL         DAL PUNJABI           DAL TADKA
# 22            PALAK SOYA WADI        LAUKI MASALA        PETHA MASALA
# 23                    CHAPATI             CHAPATI             CHAPATI
# 24              CHICKEN CURRY        CHICKEN RADA     CHICKEN BIRYANI
#
#             Unnamed: 4                     Unnamed: 5          Unnamed: 6  \
# 0             THURSDAY                         FRIDAY            SATURDAY
# 3   BUTTER Bread & JAM             BUTTER Bread & JAM  BUTTER Bread & JAM
# 4                 POHA  ALOO PARATHA \n/ MINT CHUTNEY       KULCHA MATTER
# 5           TEA/COFFEE                     TEA/COFFEE          TEA/COFFEE
# 7          GREEN SALAD                      MIX SALAD          CUBE SALAD
# 8           MINT RAITA                   BOONDI RAITA         JEERA RAITA
# 9           PLAIN RICE                      VEG PULAO          ONION RICE
# 10               RASAM                        SAMBHAR               RASAM
# 11       MUTTER RASILI                      CHANA DAL         DAL PUNJABI
# 12          PALAK CORN                    ALOO MATTER         MALAI KOFTA
# 13             CHAPATI                        CHAPATI             CHAPATI
# 14           EGG CURRY                  PALAK CHICKEN        CHICKEN RADA
# 17        KIMCHI SALAD                      MIX SALAD       MACRONI SALAD
# 18     SWEET CORN SOUP                   BOONDI RAITA           MIX RAITA
# 19      VEG MANCHURIAN                          PULAO          JEERA RICE
# 20             SAMBHAR                        SAMBHAR             SAMBHAR
# 21          FRIED RICE                     URAD RAJMA           DAL TADKA
# 22    VEG SWEET & SOUR                    PALAK KOFTA       MIX VEGETABLE
# 23             NOODLES                        CHAPATI             CHAPATI
# 24      CHILLI CHICKEN                  PALAK CHICKEN      BUTTER CHICKEN
#
#              Unnamed: 7
# 0                SUNDAY
# 3    BUTTER Bread & JAM
# 4   VEG UTTPAM /SAMBHAR
# 5            TEA/COFFEE
# 7           GREEN SALAD
# 8           JEERA RAITA
# 9       VEG DUM BIRYANI
# 10              SAMBHAR
# 11          DAL MAKHANI
# 12        BAIGAN BHARTA
# 13              CHAPATI
# 14     CHICKEN LABABDAR
# 17           CUBE SALAD
# 18         BOONDI RAITA
# 19            PEAS RICE
# 20                RASAM
# 21         DAL HARIYALI
# 22    ALOO GOBHI MASALA
# 23              CHAPATI
# 24   CHICKEN ROGAN JOSH

# %%
z=dh1.iloc[:,(1,2,3,4,5,6,7)]

# %%
z.columns=['Mon','Tue','Wed','Thu','Fri','Sat','Sun']

# %%
#z.to_json("week.json")
jsond=z.to_json("DH1.json")

# %%
jsond

# %%
import json

# %%
from pprint import pprint

with open('DH1.json') as data_file:    
    data = json.load(data_file)

pprint(data)
# Out:
# {'Fri': {'0': 'FRIDAY',
#          '10': 'SAMBHAR',
#          '11': 'CHANA DAL',
#          '12': 'ALOO MATTER',
#          '13': 'CHAPATI',
#          '14': 'PALAK CHICKEN',
#          '17': 'MIX SALAD',
#          '18': 'BOONDI RAITA',
#          '19': 'PULAO',
#          '20': 'SAMBHAR',
#          '21': 'URAD RAJMA',
#          '22': 'PALAK KOFTA',
#          '23': 'CHAPATI',
#          '24': 'PALAK CHICKEN',
#          '3': 'BUTTER Bread & JAM',
#          '4': 'ALOO PARATHA \n/ MINT CHUTNEY',
#          '5': 'TEA/COFFEE',
#          '7': 'MIX SALAD',
#          '8': 'BOONDI RAITA',
#          '9': 'VEG PULAO'},
#  'Mon': {'0': 'MONDAY',
#          '10': 'SAMBHAR',
#          '11': 'KADHI PAKORA',
#          '12': 'ALOO JEERA',
#          '13': 'CHAPATI',
#          '14': 'CHICKEN LABABDAR',
#          '17': 'LACHHA ONION',
#          '18': 'CUCUMBER RAITA',
#          '19': 'PEAS RICE',
#          '20': 'SAMBHAR',
#          '21': 'LOBIYA DAL',
#          '22': 'PALAK SOYA WADI',
#          '23': 'CHAPATI',
#          '24': 'CHICKEN CURRY',
#          '3': 'BUTTER Bread & JAM',
#          '4': 'VERMICELLI UPMA/\nCHUTNEY',
#          '5': 'TEA/COFFEE',
#          '7': 'GREEN SALAD',
#          '8': 'JEERA RAITA',
#          '9': 'PLAIN RICE'},
#  'Sat': {'0': 'SATURDAY',
#          '10': 'RASAM',
#          '11': 'DAL PUNJABI',
#          '12': 'MALAI KOFTA',
#          '13': 'CHAPATI',
#          '14': 'CHICKEN RADA',
#          '17': 'MACRONI SALAD',
#          '18': 'MIX RAITA',
#          '19': 'JEERA RICE',
#          '20': 'SAMBHAR',
#          '21': 'DAL TADKA',
#          '22': 'MIX VEGETABLE',
#          '23': 'CHAPATI',
#          '24': 'BUTTER CHICKEN',
#          '3': 'BUTTER Bread & JAM',
#          '4': 'KULCHA MATTER',
#          '5': 'TEA/COFFEE',
#          '7': 'CUBE SALAD',
#          '8': 'JEERA RAITA',
#          '9': 'ONION RICE'},
#  'Sun': {'0': 'SUNDAY',
#          '10': 'SAMBHAR',
#          '11': 'DAL MAKHANI',
#          '12': 'BAIGAN BHARTA',
#          '13': 'CHAPATI',
#          '14': 'CHICKEN LABABDAR',
#          '17': 'CUBE SALAD',
#          '18': 'BOONDI RAITA',
#          '19': 'PEAS RICE',
#          '20': 'RASAM',
#          '21': 'DAL HARIYALI',
#          '22': 'ALOO GOBHI MASALA',
#          '23': 'CHAPATI',
#          '24': 'CHICKEN ROGAN JOSH',
#          '3': 'BUTTER Bread & JAM',
#          '4': 'VEG UTTPAM /SAMBHAR',
#          '5': 'TEA/COFFEE',
#          '7': 'GREEN SALAD',
#          '8': 'JEERA RAITA',
#          '9': 'VEG DUM BIRYANI'},
#  'Thu': {'0': 'THURSDAY',
#          '10': 'RASAM',
#          '11': 'MUTTER RASILI',
#          '12': 'PALAK CORN',
#          '13': 'CHAPATI',
#          '14': 'EGG CURRY',
#          '17': 'KIMCHI SALAD',
#          '18': 'SWEET CORN SOUP',
#          '19': 'VEG MANCHURIAN',
#          '20': 'SAMBHAR',
#          '21': 'FRIED RICE',
#          '22': 'VEG SWEET & SOUR',
#          '23': 'NOODLES',
#          '24': 'CHILLI CHICKEN',
#          '3': 'BUTTER Bread & JAM',
#          '4': 'POHA',
#          '5': 'TEA/COFFEE',
#          '7': 'GREEN SALAD',
#          '8': 'MINT RAITA',
#          '9': 'PLAIN RICE'},
#  'Tue': {'0': 'TUESDAY',
#          '10': 'RASAM',
#          '11': 'DAL TADKA',
#          '12': 'MIX VEGETABLE',
#          '13': 'CHAPATI',
#          '14': 'FISH CURRY',
#          '17': 'CUBE SALAD',
#          '18': 'JEERA RAITA',
#          '19': 'ONION RICE',
#          '20': 'RASAM',
#          '21': 'DAL PUNJABI',
#          '22': 'LAUKI MASALA',
#          '23': 'CHAPATI',
#          '24': 'CHICKEN RADA',
#          '3': 'BUTTER Bread & JAM',
#          '4': 'VADA SAMBHER',
#          '5': 'TEA/COFFEE',
#          '7': 'MACRONI SALAD',
#          '8': 'MIX RAITA',
#          '9': 'JEERA RICE'},
#  'Wed': {'0': 'WEDNESDAY',
#          '10': 'SAMBER',
#          '11': 'RED MALKA',
#          '12': 'ALOO GOBHI',
#          '13': 'CHAPATI',
#          '14': 'CHICKEN CURRY',
#          '17': 'GREEN SALAD',
#          '18': 'MINT RAITA',
#          '19': 'VEG BIRYANI',
#          '20': 'RASAM',
#          '21': 'DAL TADKA',
#          '22': 'PETHA MASALA',
#          '23': 'CHAPATI',
#          '24': 'CHICKEN BIRYANI',
#          '3': 'BUTTER Bread & JAM',
#          '4': 'PAV BHAJI',
#          '5': 'TEA/COFFEE',
#          '7': 'LACHHA ONION',
#          '8': 'CUCUMBER RAITA',
#          '9': 'PEAS RICE'}}

# %%
data['Mon']
# Out:
# {'0': 'MONDAY',
#  '10': 'SAMBHAR',
#  '11': 'KADHI PAKORA',
#  '12': 'ALOO JEERA',
#  '13': 'CHAPATI',
#  '14': 'CHICKEN LABABDAR',
#  '17': 'LACHHA ONION',
#  '18': 'CUCUMBER RAITA',
#  '19': 'PEAS RICE',
#  '20': 'SAMBHAR',
#  '21': 'LOBIYA DAL',
#  '22': 'PALAK SOYA WADI',
#  '23': 'CHAPATI',
#  '24': 'CHICKEN CURRY',
#  '3': 'BUTTER Bread & JAM',
#  '4': 'VERMICELLI UPMA/\nCHUTNEY',
#  '5': 'TEA/COFFEE',
#  '7': 'GREEN SALAD',
#  '8': 'JEERA RAITA',
#  '9': 'PLAIN RICE'}

# %%
import requests
r=requests.get('https://raw.githubusercontent.com/mr-karan/SNUMessApp/master/MessJSON/DH1.json').json()

# %%
r
# Out:
# {'Fri': {'0': 'FRIDAY',
#   '10': 'SAMBHAR',
#   '11': 'CHANA DAL',
#   '12': 'ALOO MATTER',
#   '13': 'CHAPATI',
#   '14': 'PALAK CHICKEN',
#   '17': 'MIX SALAD',
#   '18': 'BOONDI RAITA',
#   '19': 'PULAO',
#   '20': 'SAMBHAR',
#   '21': 'URAD RAJMA',
#   '22': 'PALAK KOFTA',
#   '23': 'CHAPATI',
#   '24': 'PALAK CHICKEN',
#   '3': 'BUTTER Bread & JAM',
#   '4': 'ALOO PARATHA \n/ MINT CHUTNEY',
#   '5': 'TEA/COFFEE',
#   '7': 'MIX SALAD',
#   '8': 'BOONDI RAITA',
#   '9': 'VEG PULAO'},
#  'Mon': {'0': 'MONDAY',
#   '10': 'SAMBHAR',
#   '11': 'KADHI PAKORA',
#   '12': 'ALOO JEERA',
#   '13': 'CHAPATI',
#   '14': 'CHICKEN LABABDAR',
#   '17': 'LACHHA ONION',
#   '18': 'CUCUMBER RAITA',
#   '19': 'PEAS RICE',
#   '20': 'SAMBHAR',
#   '21': 'LOBIYA DAL',
#   '22': 'PALAK SOYA WADI',
#   '23': 'CHAPATI',
#   '24': 'CHICKEN CURRY',
#   '3': 'BUTTER Bread & JAM',
#   '4': 'VERMICELLI UPMA/\nCHUTNEY',
#   '5': 'TEA/COFFEE',
#   '7': 'GREEN SALAD',
#   '8': 'JEERA RAITA',
#   '9': 'PLAIN RICE'},
#  'Sat': {'0': 'SATURDAY',
#   '10': 'RASAM',
#   '11': 'DAL PUNJABI',
#   '12': 'MALAI KOFTA',
#   '13': 'CHAPATI',
#   '14': 'CHICKEN RADA',
#   '17': 'MACRONI SALAD',
#   '18': 'MIX RAITA',
#   '19': 'JEERA RICE',
#   '20': 'SAMBHAR',
#   '21': 'DAL TADKA',
#   '22': 'MIX VEGETABLE',
#   '23': 'CHAPATI',
#   '24': 'BUTTER CHICKEN',
#   '3': 'BUTTER Bread & JAM',
#   '4': 'KULCHA MATTER',
#   '5': 'TEA/COFFEE',
#   '7': 'CUBE SALAD',
#   '8': 'JEERA RAITA',
#   '9': 'ONION RICE'},
#  'Sun': {'0': 'SUNDAY',
#   '10': 'SAMBHAR',
#   '11': 'DAL MAKHANI',
#   '12': 'BAIGAN BHARTA',
#   '13': 'CHAPATI',
#   '14': 'CHICKEN LABABDAR',
#   '17': 'CUBE SALAD',
#   '18': 'BOONDI RAITA',
#   '19': 'PEAS RICE',
#   '20': 'RASAM',
#   '21': 'DAL HARIYALI',
#   '22': 'ALOO GOBHI MASALA',
#   '23': 'CHAPATI',
#   '24': 'CHICKEN ROGAN JOSH',
#   '3': 'BUTTER Bread & JAM',
#   '4': 'VEG UTTPAM /SAMBHAR',
#   '5': 'TEA/COFFEE',
#   '7': 'GREEN SALAD',
#   '8': 'JEERA RAITA',
#   '9': 'VEG DUM BIRYANI'},
#  'Thu': {'0': 'THURSDAY',
#   '10': 'RASAM',
#   '11': 'MUTTER RASILI',
#   '12': 'PALAK CORN',
#   '13': 'CHAPATI',
#   '14': 'EGG CURRY',
#   '17': 'KIMCHI SALAD',
#   '18': 'SWEET CORN SOUP',
#   '19': 'VEG MANCHURIAN',
#   '20': 'SAMBHAR',
#   '21': 'FRIED RICE',
#   '22': 'VEG SWEET & SOUR',
#   '23': 'NOODLES',
#   '24': 'CHILLI CHICKEN',
#   '3': 'BUTTER Bread & JAM',
#   '4': 'POHA',
#   '5': 'TEA/COFFEE',
#   '7': 'GREEN SALAD',
#   '8': 'MINT RAITA',
#   '9': 'PLAIN RICE'},
#  'Tue': {'0': 'TUESDAY',
#   '10': 'RASAM',
#   '11': 'DAL TADKA',
#   '12': 'MIX VEGETABLE',
#   '13': 'CHAPATI',
#   '14': 'FISH CURRY',
#   '17': 'CUBE SALAD',
#   '18': 'JEERA RAITA',
#   '19': 'ONION RICE',
#   '20': 'RASAM',
#   '21': 'DAL PUNJABI',
#   '22': 'LAUKI MASALA',
#   '23': 'CHAPATI',
#   '24': 'CHICKEN RADA',
#   '3': 'BUTTER Bread & JAM',
#   '4': 'VADA SAMBHER',
#   '5': 'TEA/COFFEE',
#   '7': 'MACRONI SALAD',
#   '8': 'MIX RAITA',
#   '9': 'JEERA RICE'},
#  'Wed': {'0': 'WEDNESDAY',
#   '10': 'SAMBER',
#   '11': 'RED MALKA',
#   '12': 'ALOO GOBHI',
#   '13': 'CHAPATI',
#   '14': 'CHICKEN CURRY',
#   '17': 'GREEN SALAD',
#   '18': 'MINT RAITA',
#   '19': 'VEG BIRYANI',
#   '20': 'RASAM',
#   '21': 'DAL TADKA',
#   '22': 'PETHA MASALA',
#   '23': 'CHAPATI',
#   '24': 'CHICKEN BIRYANI',
#   '3': 'BUTTER Bread & JAM',
#   '4': 'PAV BHAJI',
#   '5': 'TEA/COFFEE',
#   '7': 'LACHHA ONION',
#   '8': 'CUCUMBER RAITA',
#   '9': 'PEAS RICE'}}

# %%
breakfast=[r['Mon'][str(i)] for i in range(3,6)]
lunch=[r['Mon'][str(i)]for i in range(7,15)]
dinner=[r['Mon'][str(i)] for i in range(17,25)]

# %%
r['Mon']
# Out:
# {'0': 'MONDAY',
#  '10': 'SAMBHAR',
#  '11': 'KADHI PAKORA',
#  '12': 'ALOO JEERA',
#  '13': 'CHAPATI',
#  '14': 'CHICKEN LABABDAR',
#  '17': 'LACHHA ONION',
#  '18': 'CUCUMBER RAITA',
#  '19': 'PEAS RICE',
#  '20': 'SAMBHAR',
#  '21': 'LOBIYA DAL',
#  '22': 'PALAK SOYA WADI',
#  '23': 'CHAPATI',
#  '24': 'CHICKEN CURRY',
#  '3': 'BUTTER Bread & JAM',
#  '4': 'VERMICELLI UPMA/\nCHUTNEY',
#  '5': 'TEA/COFFEE',
#  '7': 'GREEN SALAD',
#  '8': 'JEERA RAITA',
#  '9': 'PLAIN RICE'}

# %%
z
# Out:
#                       Mon                 Tue                 Wed  \
# 0                  Monday             Tuesday           Wednesday
# 1       26th October 2015   27th October 2015   28th October 2015
# 3      Bread Butter & Jam  Bread Butter & Jam  Bread Butter & Jam
# 4       Poha/Mint chutney          Sooji Upma              Daliya
# 5            Tea / Coffee        Tea / Coffee        Tea / Coffee
# 7   Allo chana chat salad         Green Salad    Matar chat salad
# 8             Ghiya Raita               Papad      Cucumber Raita
# 9              Onion Rice          Onion Rice         Tomato Rice
# 10                Sambhar               Rasam             Sambhar
# 11       Muttera rassedar        Kadhi pakora         Malka Black
# 12              Veg Kofta          Aloo Jeera         Ghiya chana
# 13                Chapati             Chapati             Chapati
# 14          Chicken Curry           Egg Curry           Murg Rada
# 17           Kimchi Salad           Mix Salad           Mix Salad
# 18            Jeera Raita        Pudina Raita         Jeera Raita
# 19             Plain Rice          Jeera Rice          Plain Rice
# 20                  Rasam             Sambhar               Rasam
# 21        Rajama Rassedar      Kala chana dal        Doodhi Chana
# 22            Tori masala       Palak Soywadi       Baigan Bharta
# 23                Chapati             Chapati             Chapati
# 24             Murg Korma       Murg Hariyali        Murg Makhani
#
#                      Thu                        Fri                 Sat  \
# 0               Thursday                     Friday            Saturday
# 1      29th October 2015          30th October 2015   31st October 2015
# 3     Bread Butter & Jam         Bread Butter & Jam  Bread Butter & Jam
# 4   Mini Uttapam/Sambhar  Besan chilla/Mint Chutney     Vermicelli Upma
# 5           Tea / Coffee               Tea / Coffee        Tea / Coffee
# 7            Green Salad              Sprouts salad    Matar Chat salad
# 8             Mint Raita                Papdi Raita         Jeera Raita
# 9             Plain Rice                  Veg Pulao          Plain Rice
# 10                 Rasam                Dal Makhani               Rasam
# 11         Mix DAL Tadka            Paneer Lababdar       Rajama Masala
# 12     Besan Gatta Curry                    Chapati   Kashmiri dum aloo
# 13               Chapati             Cococnut Ladoo             Chapati
# 14            Murg Korma           Chicken Lababdar        Murg Makhani
# 17     Lobiya chat salad                Green Salad           Mix Salad
# 18           Papdi Raita                      Papad         Butter Milk
# 19             Veg Pulao                 Onion Rice          Lemon Rice
# 20               Sambhar                    Sambhar             Sambhar
# 21         Rajama masala               Kadhi pakora               Rasam
# 22          Lauki Masala                 Aloo Jeera         Veg Poriyal
# 23               Chapati                    Chapati             Chapati
# 24         Chicken Curry                  Egg Curry   Chicken chettinad
#
#                    Sun
# 0               Sunday
# 1    1st November 2015
# 3   Bread Butter & Jam
# 4            Pao/Bhaji
# 5         Tea / Coffee
# 7    Lobiya Chat salad
# 8            Veg Raita
# 9           Plain Rice
# 10               Rasam
# 11    Muttera Rassedar
# 12       Baigan bharta
# 13             Chapati
# 14           Egg curry
# 17           Mix salad
# 18      Cucumber Raita
# 19         Tomato Rice
# 20             Sambhar
# 21       Rajama masala
# 22     Palak soya wadi
# 23             Chapati
# 24           Murg Rada

# %%
breakfast
# Out:
# ['BUTTER Bread & JAM', 'VERMICELLI UPMA/\nCHUTNEY', 'TEA/COFFEE']
